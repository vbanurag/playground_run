# %%
pip install ollama-ocr
# Out:
# Requirement already satisfied: ollama-ocr in /Users/anuragsharma/.pyenv/versions/python-play/lib/python3.11/site-packages (0.1.6)
# Requirement already satisfied: Pillow in /Users/anuragsharma/.pyenv/versions/python-play/lib/python3.11/site-packages (from ollama-ocr) (11.3.0)
# Requirement already satisfied: requests in /Users/anuragsharma/.pyenv/versions/python-play/lib/python3.11/site-packages (from ollama-ocr) (2.32.4)
# Requirement already satisfied: python-magic in /Users/anuragsharma/.pyenv/versions/python-play/lib/python3.11/site-packages (from ollama-ocr) (0.4.27)
# Requirement already satisfied: transformers in /Users/anuragsharma/.pyenv/versions/python-play/lib/python3.11/site-packages (from ollama-ocr) (4.55.2)
# Requirement already satisfied: streamlit in /Users/anuragsharma/.pyenv/versions/python-play/lib/python3.11/site-packages (from ollama-ocr) (1.48.1)
# Requirement already satisfied: tqdm in /Users/anuragsharma/.pyenv/versions/python-play/lib/python3.11/site-packages (from ollama-ocr) (4.67.1)
# Requirement already satisfied: opencv-python in /Users/anuragsharma/.pyenv/versions/python-play/lib/python3.11/site-packages (from ollama-ocr) (4.12.0.88)
# Requirement already satisfied: pdf2image in /Users/anuragsharma/.pyenv/versions/python-play/lib/python3.11/site-packages (from ollama-ocr) (1.17.0)
# Requirement already satisfied: numpy in /Users/anuragsharma/.pyenv/versions/python-play/lib/python3.11/site-packages (from ollama-ocr) (2.2.6)
# Requirement already satisfied: pymupdf in /Users/anuragsharma/.pyenv/versions/python-play/lib/python3.11/site-packages (from ollama-ocr) (1.26.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/anuragsharma/.pyenv/versions/python-play/lib/python3.11/site-packages (from requests->ollama-ocr) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/anuragsharma/.pyenv/versions/python-play/lib/python3.11/site-packages (from requests->ollama-ocr) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/anuragsharma/.pyenv/versions/python-play/lib/python3.11/site-packages (from requests->ollama-ocr) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/anuragsharma/.pyenv/versions/python-play/lib/python3.11/site-packages (from requests->ollama-ocr) (2025.8.3)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<6,>=4.0 in /Users/anuragsharma/.pyenv/versions/python-play/lib/python3.11/site-packages (from streamlit->ollama-ocr) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /Users/anuragsharma/.pyenv/versions/python-play/lib/python3.11/site-packages (from streamlit->ollama-ocr) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in /Users/anuragsharma/.pyenv/versions/python-play/lib/python3.11/site-packages (from streamlit->ollama-ocr) (6.1.0)
# Requirement already satisfied: click<9,>=7.0 in /Users/anuragsharma/.pyenv/versions/python-play/lib/python3.11/site-packages (from streamlit->ollama-ocr) (8.2.1)
# Requirement already satisfied: packaging<26,>=20 in /Users/anuragsharma/.pyenv/versions/python-play/lib/python3.11/site-packages (from streamlit->ollama-ocr) (25.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in /Users/anuragsharma/.pyenv/versions/python-play/lib/python3.11/site-packages (from streamlit->ollama-ocr) (2.3.1)
# Requirement already satisfied: protobuf<7,>=3.20 in /Users/anuragsharma/.pyenv/versions/python-play/lib/python3.11/site-packages (from streamlit->ollama-ocr) (6.31.1)
# Requirement already satisfied: pyarrow>=7.0 in /Users/anuragsharma/.pyenv/versions/python-play/lib/python3.11/site-packages (from streamlit->ollama-ocr) (21.0.0)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /Users/anuragsharma/.pyenv/versions/python-play/lib/python3.11/site-packages (from streamlit->ollama-ocr) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in /Users/anuragsharma/.pyenv/versions/python-play/lib/python3.11/site-packages (from streamlit->ollama-ocr) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /Users/anuragsharma/.pyenv/versions/python-play/lib/python3.11/site-packages (from streamlit->ollama-ocr) (4.14.1)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /Users/anuragsharma/.pyenv/versions/python-play/lib/python3.11/site-packages (from streamlit->ollama-ocr) (3.1.45)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /Users/anuragsharma/.pyenv/versions/python-play/lib/python3.11/site-packages (from streamlit->ollama-ocr) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in /Users/anuragsharma/.pyenv/versions/python-play/lib/python3.11/site-packages (from streamlit->ollama-ocr) (6.5.2)
# Requirement already satisfied: filelock in /Users/anuragsharma/.pyenv/versions/python-play/lib/python3.11/site-packages (from transformers->ollama-ocr) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /Users/anuragsharma/.pyenv/versions/python-play/lib/python3.11/site-packages (from transformers->ollama-ocr) (0.34.4)
# Requirement already satisfied: pyyaml>=5.1 in /Users/anuragsharma/.pyenv/versions/python-play/lib/python3.11/site-packages (from transformers->ollama-ocr) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /Users/anuragsharma/.pyenv/versions/python-play/lib/python3.11/site-packages (from transformers->ollama-ocr) (2025.7.34)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /Users/anuragsharma/.pyenv/versions/python-play/lib/python3.11/site-packages (from transformers->ollama-ocr) (0.21.4)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/anuragsharma/.pyenv/versions/python-play/lib/python3.11/site-packages (from transformers->ollama-ocr) (0.6.2)
# Requirement already satisfied: jinja2 in /Users/anuragsharma/.pyenv/versions/python-play/lib/python3.11/site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit->ollama-ocr) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /Users/anuragsharma/.pyenv/versions/python-play/lib/python3.11/site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit->ollama-ocr) (4.25.0)
# Requirement already satisfied: narwhals>=1.14.2 in /Users/anuragsharma/.pyenv/versions/python-play/lib/python3.11/site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit->ollama-ocr) (2.1.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/anuragsharma/.pyenv/versions/python-play/lib/python3.11/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit->ollama-ocr) (4.0.12)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/anuragsharma/.pyenv/versions/python-play/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers->ollama-ocr) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/anuragsharma/.pyenv/versions/python-play/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers->ollama-ocr) (1.1.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/anuragsharma/.pyenv/versions/python-play/lib/python3.11/site-packages (from pandas<3,>=1.4.0->streamlit->ollama-ocr) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/anuragsharma/.pyenv/versions/python-play/lib/python3.11/site-packages (from pandas<3,>=1.4.0->streamlit->ollama-ocr) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/anuragsharma/.pyenv/versions/python-play/lib/python3.11/site-packages (from pandas<3,>=1.4.0->streamlit->ollama-ocr) (2025.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/anuragsharma/.pyenv/versions/python-play/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit->ollama-ocr) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/anuragsharma/.pyenv/versions/python-play/lib/python3.11/site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit->ollama-ocr) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /Users/anuragsharma/.pyenv/versions/python-play/lib/python3.11/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit->ollama-ocr) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/anuragsharma/.pyenv/versions/python-play/lib/python3.11/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit->ollama-ocr) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/anuragsharma/.pyenv/versions/python-play/lib/python3.11/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit->ollama-ocr) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/anuragsharma/.pyenv/versions/python-play/lib/python3.11/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit->ollama-ocr) (0.27.0)
# Requirement already satisfied: six>=1.5 in /Users/anuragsharma/.pyenv/versions/python-play/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit->ollama-ocr) (1.17.0)
#
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import cv2

def rotate_to_horizontal(image):
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    edges = cv2.Canny(gray, 50, 150, apertureSize=3)
    lines = cv2.HoughLinesP(edges, 1, np.pi / 180, 100, minLineLength=100, maxLineGap=10)
    
    angles = []
    for line in lines:
        x1, y1, x2, y2 = line[0]
        angle = np.degrees(np.arctan2(y2 - y1, x2 - x1))
        angles.append(angle)
    
    median_angle = np.median(angles)
    if abs(median_angle) > 45:  # Rotate only if text is significantly skewed
        (h, w) = image.shape[:2]
        center = (w // 2, h // 2)
        rotation_matrix = cv2.getRotationMatrix2D(center, median_angle, 1.0)
        rotated_image = cv2.warpAffine(image, rotation_matrix, (w, h), flags=cv2.INTER_CUBIC)
        return rotated_image
    return image

# Correct orientation
corrected_image = rotate_to_horizontal(cv2.imread('test.JPG'))
cv2.imwrite("corrected.jpg", corrected_image)  # Save corrected image
# Out:
# True

# %%
text = """
You are an intelligent parser that extracts structured invoice data from raw OCR text and returns it as JSON.

Your responsibilities:
1. Parse all relevant fields:
   - Vendor details (name, address, contact, GSTIN)
   - Invoice number and date
   - Customer billing and shipping info
   - Bank account details (bank name, account number, IFSC, UPI ID if available)
   - Final invoice totals (subtotal, tax breakdown, grand total)
   - Line items with full breakdown

2. Do not miss any line items. Each must include:
   - description
   - hsn
   - uom
   - quantity
   - rate
   - taxable_value
   - cgst (rate, amount)
   - sgst (rate, amount)

3. All tax amounts (CGST, SGST, IGST) and totals must match what's present in the text.

Return only valid JSON, following this structure exactly:
{
  "vendor": {
    "name": ...,
    "address": ...,
    "contact": [...],
    "gstin": ...
  },
  "invoice": {
    "number": ...,
    "date": ...
  },
  "bill_to": {
    "name": ...,
    "address": ...
  },
  "ship_to": {
    "name": ...,
    "address": ...
  },
  "bank_details": {
    "bank_name": ...,
    "account_number": ...,
    "ifsc": ...,
    "upi_id": ...
  },
  "line_items": [
    {
      "sno": ...,
      "description": ...,
      "hsn": ...,
      "uom": ...,
      "quantity": ...,
      "rate": ...,
      "taxable_value": ...,
      "cgst": {
        "rate": ...,
        "amount": ...
      },
      "sgst": {
        "rate": ...,
        "amount": ...
      }
    }
  ],
  "total": {
    "subtotal": ...,
    "cgst_total": ...,
    "sgst_total": ...,
    "igst_total": ...,
    "grand_total": ...
  }
}
"""

# %%
from ollama_ocr import OCRProcessor

# Initialize OCR processor
ocr = OCRProcessor(model_name='llama3.2-vision:11b', max_workers=4)  # You can use any vision model available on Ollama
# you can pass your custom ollama api

# Process an image
result = ocr.process_image(
    image_path="../ocr_parser/2.jpg", # path to your pdf files "path/to/your/file.pdf"
    format_type="text",  # Options: markdown, text, json, structured, key_value
    preprocess=True, 
    
    custom_prompt=text, # Optional custom prompt
    language="English" # Specify the language of the text (New! 🆕)
)
print(result)
# Out:
# Using custom prompt:
# You are an intelligent parser that extracts structured invoice data from raw OCR text and returns it as JSON.
#
# Your responsibilities:
# 1. Parse all relevant fields:
#    - Vendor details (name, address, contact, GSTIN)
#    - Invoice number and date
#    - Customer billing and shipping info
#    - Bank account details (bank name, account number, IFSC, UPI ID if available)
#    - Final invoice totals (subtotal, tax breakdown, grand total)
#    - Line items with full breakdown
#
# 2. Do not miss any line items. Each must include:
#    - description
#    - hsn
#    - uom
#    - quantity
#    - rate
#    - taxable_value
#    - cgst (rate, amount)
#    - sgst (rate, amount)
#
# 3. All tax amounts (CGST, SGST, IGST) and totals must match what's present in the text.
#
# Return only valid JSON, following this structure exactly:
# {
#   "vendor": {
#     "name": ...,
#     "address": ...,
#     "contact": [...],
#     "gstin": ...
#   },
#   "invoice": {
#     "number": ...,
#     "date": ...
#   },
#   "bill_to": {
#     "name": ...,
#     "address": ...
#   },
#   "ship_to": {
#     "name": ...,
#     "address": ...
#   },
#   "bank_details": {
#     "bank_name": ...,
#     "account_number": ...,
#     "ifsc": ...,
#     "upi_id": ...
#   },
#   "line_items": [
#     {
#       "description": ...,
#       "hsn": ...,
#       "uom": ...,
#       "quantity": ...,
#       "rate": ...,
#       "taxable_value": ...,
#       "cgst": {
#         "rate": ...,
#         "amount": ...
#       },
#       "sgst": {
#         "rate": ...,
#         "amount": ...
#       }
#     }
#   ],
#   "total": {
#     "subtotal": ...,
#     "cgst_total": ...,
#     "sgst_total": ...,
#     "igst_total": ...,
#     "grand_total": ...
#   }
# }
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 8
#       4 ocr = OCRProcessor(model_name='llama3.2-vision:11b', max_workers=4)  # You can use any vision model available on Ollama
#       5 # you can pass your custom ollama api
#       6
#       7 # Process an image
# ----> 8 result = ocr.process_image(
#       9     image_path="../ocr_parser/2.jpg", # path to your pdf files "path/to/your/file.pdf"
#      10     format_type="text",  # Options: markdown, text, json, structured, key_value
#      11     preprocess=True,
#      12
#      13     custom_prompt=text, # Optional custom prompt
#      14     language="English" # Specify the language of the text (New! 🆕)
#      15 )
#      16 print(result)
#
# File ~/.pyenv/versions/python-play/lib/python3.11/site-packages/ollama_ocr/ocr_processor.py:273, in OCRProcessor.process_image(self, image_path, format_type, preprocess, custom_prompt, language)
#     264     print("Using default prompt:", prompt)  # Debug print
#     266 payload = {
#     267     "model": self.model_name,
#     268     "prompt": prompt,
#     269     "stream": False,
#     270     "images": [image_base64]
#     271 }
# --> 273 response = requests.post(self.base_url, json=payload)
#     274 response.raise_for_status()
#     276 result = response.json().get("response", "")
#
# File ~/.pyenv/versions/python-play/lib/python3.11/site-packages/requests/api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)    112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File ~/.pyenv/versions/python-play/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/.pyenv/versions/python-play/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/.pyenv/versions/python-play/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/.pyenv/versions/python-play/lib/python3.11/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/.pyenv/versions/python-play/lib/python3.11/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/.pyenv/versions/python-play/lib/python3.11/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/.pyenv/versions/python-play/lib/python3.11/site-packages/urllib3/connection.py:565, in HTTPConnection.getresponse(self)
#     562 _shutdown = getattr(self.sock, "shutdown", None)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#     568     assert_header_parsing(httplib_response.msg)
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/http/client.py:1395, in HTTPConnection.getresponse(self)
#    1393 try:
#    1394     try:
# -> 1395         response.begin()
#    1396     except ConnectionError:
#    1397         self.close()
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/http/client.py:325, in HTTPResponse.begin(self)
#     323 # read until we get a non-100 response
#     324 while True:
# --> 325     version, status, reason = self._read_status()
#     326     if status != CONTINUE:
#     327         break
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/http/client.py:286, in HTTPResponse._read_status(self)
#     285 def _read_status(self):
# --> 286     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287     if len(line) > _MAXLINE:
#     288         raise LineTooLong("status line")
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# KeyboardInterrupt:
